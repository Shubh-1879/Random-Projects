# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubh-1879/Random-Projects/blob/main/CNN_Bear_Shubham.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importing Libraries

# %%
! [ -e /content ] && pip install -Uqq fastai

# %% [markdown]
# The above cell is to upgrade fastai on colab (from here: https://github.com/fastai/fastai/blob/master/nbs/10_tutorial.pets.ipynb)
#
# !: To indicate that the following command should be executed in the the command line rather than as Python code.
#
# [ -e /content ]: Checks if a file or directory exists.
#
# -U: Flag - for "upgrade". Tells pip to upgrade the package to the latest version if it's already installed.
#
# -qq: "quiet" mode. The -q option reduces the output of the command. Using -qq makes it even quieter, suppressing all output except for errors.

# %%
from fastai.vision.all import *
from fastai.vision.widgets import *
from fastdownload import download_url

# %% [markdown]
# Importing all necessary tools, modules, functions from fastai and fastdownload library

# %% [markdown]
# ### Mounting Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ## Dataset
# CNNs come under Supervised Learning, so we need to have a labelled dataset.
#
# Making the dataset using Bing Image search.

# %% [markdown]
# ### Downloading A Dataset
#
# Using Bing's search engine, we'll get 80 images each for 'grizzly bear', 'black bear' and 'teddy bear' and save them in our drive.

# %%
pip install -q bing-image-downloader

# %% [markdown]
# Installing Bing's image downloader

# %%
import os
import contextlib
from bing_image_downloader import downloader
from pathlib import Path
path = Path().cwd()/"Bears" #appends the "Bears" directory to the current working directory path

numberOfImagesForEachClass = 80 # downloading 80 images for each bear type

bear_types = ['grizzly bear', 'polar bear', 'black bear']

with contextlib.redirect_stdout(open(os.devnull, 'w')): #to curb output lines; to redirect the output to suppress print statements from the bing_image_downloader library
  for o in bear_types:
    downloader.download(o,  limit=numberOfImagesForEachClass,  output_dir=path, adult_filter_off=True, force_replace=False)

# %% [markdown]
# How suppressing the output works:
#
# *with contextlib.redirect_stdout(open(os.devnull, 'w')):*
#
# This line starts a context manager to suppress any output (such as print statements) that would normally be printed to the console.
#
# *open(os.devnull, 'w'):* opens a special file-like object called os.devnull. Anything written to os.devnull is discarded, effectively silencing any output.
#
# *contextlib.redirect_stdout():* temporarily redirects all output (stdout) to os.devnull, silencing it.

# %% [markdown]
# Our folder 'Bears' now has the downloaded images. Running the code below to see their saved path in the drive.

# %%
fns = get_image_files(path)
fns
# Out:
# (#264) [Path('/content/Bears/black bear/Image_29.jpg'),Path('/content/Bears/black bear/Image_41.png'),Path('/content/Bears/black bear/Image_58.jpg'),Path('/content/Bears/black bear/Image_76.jpg'),Path('/content/Bears/black bear/Image_54.jpg'),Path('/content/Bears/black bear/Image_80.jpg'),Path('/content/Bears/black bear/Image_65.jpg'),Path('/content/Bears/black bear/Image_59.jpg'),Path('/content/Bears/black bear/Image_24.jpg'),Path('/content/Bears/black bear/Image_11.jpg')...]

# %% [markdown]
# ## Data Pipelining
#
# Using DataLoaders class of fastai to format the data for training the model.

# %%
bears = DataBlock(
    blocks=(ImageBlock, CategoryBlock), #Had a doubt here
    get_items=get_image_files,
    splitter=RandomSplitter(valid_pct=0.2, seed=42), #20% of the images will be used as the validation set, and 80% will be used for training
    get_y=parent_label,
    item_tfms=Resize(128))
dls = bears.dataloaders(path)

# %% [markdown]
# Sample images from our dataset.

# %%
dls.valid.show_batch(max_n=8, nrows=2)

# %% [markdown]
# ### Data Augmentation
#
# Epoch => one complete pass through all of our images in the dataset
#
# On each epoch, randomly select a part of the image, and crop to that part.
# This is done to imitate and account for real world circumstances where image of the same object may be slightly different, e.g. same image rotated by a few degrees. Parts of image that are repeated over several epochs are better "recognised".

# %%
bears = bears.new(item_tfms=RandomResizedCrop(128, min_scale=0.3))
# first crops a random portion of the image, then resizes that portion to the specified size (128x128);
# the minimum size of the crop. In this case, the cropped portion will be at
# least 30% of the original image size
dls = bears.dataloaders(path)
dls.train.show_batch(max_n=4, nrows=1, unique=True)

# %% [markdown]
# unique=True is used to have the same image repeated with different versions of this RandomResizedCrop transform

# %% [markdown]
# ## Training the Model

# %%
bears = bears.new(
    item_tfms=RandomResizedCrop(224, min_scale=0.5),
    batch_tfms=aug_transforms())
dls = bears.dataloaders(path)

# %% [markdown]
# Using fastAI's cnn_learner function to train the model

# %%
learn = cnn_learner(dls, resnet18, metrics=error_rate)
epochs = 3 #The more the number of epochs, the more accurate are the results from the model (tried with different values of epochs)
learn.fine_tune(epochs)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.463299</td>
#       <td>0.358419</td>
#       <td>0.134615</td>
#       <td>01:08</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.687210</td>
#       <td>0.211465</td>
#       <td>0.076923</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.519906</td>
#       <td>0.198473</td>
#       <td>0.038462</td>
#       <td>01:18</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.422816</td>
#       <td>0.213677</td>
#       <td>0.038462</td>
#       <td>01:21</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Creating confusion matrix to visualise actual vs predicted class of bears

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# ## Testing the trained model on custom input

# %% [markdown]
# ### Saving the model
# 2 parts of the model:
#  - architecture
#  - trained parameters
#
#
# Using fastai's export function, the file is saved as"export.pkl":

# %%
learn.export()

# %% [markdown]
# We now load the saved model "export.pkl"

# %%
path = Path()
path.ls(file_exts='.pkl')
learn_inf = load_learner(path/'export.pkl')

# %% [markdown]
# Taking custom input from the user and testing our model's performance on that image

# %%
# Create an output widget to display the uploaded image
out_pl = widgets.Output()
out_pl.clear_output()

# Label widget to display the model's prediction
lbl_pred = widgets.Label()

# Button to trigger image classification
btn_run = widgets.Button(description='Classify')

# File upload widget to allow users to upload an image
btn_upload = widgets.FileUpload()


def on_click_classify(change):
    # To read the uploaded image
    img = PILImage.create(btn_upload.data[-1])

    # Clear previous output and display the new image
    out_pl.clear_output()
    with out_pl:
        display(img.to_thumb(256, 256))

    # Perform prediction using the trained model
    pred, pred_idx, probs = learn_inf.predict(img)

    # Update label with prediction results
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

# Attach the function to the button's click event
btn_run.on_click(on_click_classify)

# %% [markdown]
# ### Checking our Model's prediction
#
# - Download an image of any of the classes (grizzly bear, black bear, teddy bear)
#
# - upload it by running the code snippet below
#
# - click on 'Classify'

# %%
#hide_output
VBox([widgets.Label('Select your bear!'),
      btn_upload, btn_run, out_pl, lbl_pred])
# Out:
# VBox(children=(Label(value='Select your bear!'), FileUpload(value={'Original_WW215278.jpg': {'metadata': {'nam…

# %% [markdown]
# ## References
#
# The above tutorial is taken from fast.ai's course Practical Deep Learning for coders.
# - reattempted from Satripta Makhija's tutorial by Shubham Agarwal
